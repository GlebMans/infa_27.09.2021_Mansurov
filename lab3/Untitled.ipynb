# %%
import pygame
from pygame.draw import *

clock = pygame.time.Clock()
clock.tick(30)

pygame.init()

screen = pygame.display.set_mode((700, 600))

pygame.display.update()

while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-b1c0775f78f4> in <module>
#      12
#      13 while True:
# ---> 14     for event in pygame.event.get():
#      15         if event.type == pygame.QUIT:
#      16             pygame.quit()
#
# error: video system not initialized

# %%
import pygame
from pygame.draw import *

pygame.init()

FPS = 30
screen = pygame.display.set_mode((400, 400))

rect(screen, (255, 0, 255), (100, 100, 200, 200))
rect(screen, (0, 0, 255), (100, 100, 200, 200), 5)
polygon(screen, (255, 255, 0), [(100,100), (200,50),
                               (300,100), (100,100)])
polygon(screen, (0, 0, 255), [(100,100), (200,50),
                               (300,100), (100,100)], 5)
circle(screen, (0, 255, 0), (200, 175), 50)
circle(screen, (255, 255, 255), (200, 175), 50, 5)

pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()

# %%
import pygame
from pygame.draw import *

pygame.init()

FPS = 30
screen = pygame.display.set_mode((400, 400))

x1 = 100; y1 = 100
x2 = 300; y2 = 200
N = 10
color = (255, 255, 255)
rect(screen, color, (x1, y1, x2 - x1, y2 - y1), 2)
h = (x2 - x1) // (N + 1)
x = x1 + h
for i in range(N):
    line(screen, color, (x, y1), (x, y2))
    x += h

pygame.display.update()
clock = pygame.time.Clock()
finished = False

while not finished:
    clock.tick(FPS)
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            finished = True

pygame.quit()

# %%
pygame.init()

FPS = 30
screen = pygame.display.set_mode((400, 600))

rect(screen, (101, 67, 33), (0, 0, 400, 300)) 
rect(screen, (172, 183, 142), (0, 300, 400, 300))


#window
rect(screen, (209, 237, 242), (200, 20, 180, 260))

rect(screen, (0, 191, 255), (210, 30, 75, 115))
rect(screen, (0, 191, 255), (295, 30, 75, 115))

rect(screen, (0, 191, 255), (210, 155, 75, 115))
rect(screen, (0, 191, 255), (295, 155, 75, 115))

#cat
ellipse(screen, (0, 0, 0), (98, 348, 205, 104), 2)
ellipse(screen, (205, 133, 63), (100, 350, 200, 100))

circle(screen, (205, 133, 63), (100, 350), 40)
circle(screen, (0, 0, 0), (100, 350), 42, 2)

circle(screen, (119, 221, 119), (85, 340), 10)
circle(screen, (0, 0, 0), (85, 340), 10, 1)
circle(screen, (119, 221, 119), (115, 340), 10)
circle(screen, (0, 0, 0), (115, 340), 10, 1)

circle(screen, (205, 133, 63), (250, 450), 35)
circle(screen, (0, 0, 0), (250, 450), 35, 1)

pygame.display.update()
clock = pygame.time.Clock()
finished = False
